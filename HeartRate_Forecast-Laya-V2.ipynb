# %% [markdown]
# ### Heart Rate Forecast - Regression Problem

# %%
# Import Dependancies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression,Ridge,Lasso
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
fdf_train=pd.read_csv("Train Data/frequency_domain_features_train.csv")
fdf_train.head()
# Out:
#                                    uuid          VLF    VLF_PCT           LF  \
# 0  89df2855-56eb-4706-a23b-b39363dd605a  2661.894136  72.203287  1009.249419
# 1  80c795e4-aa56-4cc0-939c-19634b89cbb2  2314.265450  76.975728   690.113275
# 2  c2d5d102-967c-487d-88f2-8b005a449f3e  1373.887112  51.152225  1298.222619
# 3  37eabc44-1349-4040-8896-0d113ad4811f  2410.357408  70.180308  1005.981659
# 4  aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  1151.177330  43.918366  1421.782051
#
#       LF_PCT      LF_NU         HF    HF_PCT     HF_NU           TP  \
# 0  27.375666  98.485263  15.522603  0.421047  1.514737  3686.666157
# 1  22.954139  99.695397   2.108525  0.070133  0.304603  3006.487251
# 2  48.335104  98.950472  13.769729  0.512671  1.049528  2685.879461
# 3  29.290305  98.224706  18.181913  0.529387  1.775294  3434.520980
# 4  54.242160  96.720007  48.215822  1.839473  3.279993  2621.175204
#
#         LF_HF     HF_LF
# 0   65.018055  0.015380
# 1  327.296635  0.003055
# 2   94.280910  0.010607
# 3   55.328701  0.018074
# 4   29.487873  0.033912

# %%
hr_train=pd.read_csv("Train Data/heart_rate_non_linear_features_train.csv")
hr_train.head()
# Out:
#                                    uuid        SD1         SD2    sampen  \
# 0  89df2855-56eb-4706-a23b-b39363dd605a  11.001565  199.061782  2.139754
# 1  80c795e4-aa56-4cc0-939c-19634b89cbb2   9.170129  114.634458  2.174499
# 2  c2d5d102-967c-487d-88f2-8b005a449f3e  11.533417  118.939253  2.135350
# 3  37eabc44-1349-4040-8896-0d113ad4811f  11.119476  127.318597  2.178341
# 4  aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  13.590641   87.718281  2.221121
#
#      higuci  datasetId     condition
# 0  1.163485          2     no stress
# 1  1.084711          2  interruption
# 2  1.176315          2  interruption
# 3  1.179688          2     no stress
# 4  1.249612          2     no stress

# %%
td_train=pd.read_csv("Train Data/time_domain_features_train.csv")
td_train.head()
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  885.157845  853.763730  140.972741  15.554505  15.553371    9.063146
# 1  939.425371  948.357865   81.317742  12.964439  12.964195    6.272369
# 2  898.186047  907.006860   84.497236  16.305279  16.305274    5.182201
# 3  881.757865  893.460030   90.370537  15.720468  15.720068    5.748591
# 4  809.625331  811.184865   62.766242  19.213819  19.213657    3.266724
#
#           HR      pNN25     pNN50      KURT      SKEW  MEAN_REL_RR  \
# 0  69.499952  11.133333  0.533333 -0.856554  0.335218    -0.000203
# 1  64.363150   5.600000  0.000000 -0.408190 -0.155286    -0.000059
# 2  67.450066  13.066667  0.200000  0.351789 -0.656813    -0.000011
# 3  68.809562  11.800000  0.133333 -0.504947 -0.386138     0.000112
# 4  74.565728  20.200000  0.200000 -0.548408 -0.154252    -0.000100
#
#    MEDIAN_REL_RR  SDRR_REL_RR  RMSSD_REL_RR  SDSD_REL_RR  SDRR_RMSSD_REL_RR  \
# 0      -0.000179     0.017080      0.007969     0.007969           2.143342
# 1       0.000611     0.013978      0.004769     0.004769           2.930855
# 2      -0.000263     0.018539      0.008716     0.008716           2.127053
# 3       0.000494     0.017761      0.008660     0.008660           2.050988
# 4      -0.002736     0.023715      0.013055     0.013055           1.816544
#
#    KURT_REL_RR  SKEW_REL_RR                                  uuid
# 0    -0.856554     0.335218  89df2855-56eb-4706-a23b-b39363dd605a
# 1    -0.408190    -0.155286  80c795e4-aa56-4cc0-939c-19634b89cbb2
# 2     0.351789    -0.656813  c2d5d102-967c-487d-88f2-8b005a449f3e
# 3    -0.504947    -0.386138  37eabc44-1349-4040-8896-0d113ad4811f
# 4    -0.548408    -0.154252  aa777a6a-7aa3-4f6e-aced-70f8691dd2b7

# %%
merge1=fdf_train.set_index('uuid').join(hr_train.set_index('uuid'))

# %%
train_df=merge1.join(td_train.set_index('uuid'))
train_df.head()
# Out:
#                                               VLF    VLF_PCT           LF  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a  2661.894136  72.203287  1009.249419
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  2314.265450  76.975728   690.113275
# c2d5d102-967c-487d-88f2-8b005a449f3e  1373.887112  51.152225  1298.222619
# 37eabc44-1349-4040-8896-0d113ad4811f  2410.357408  70.180308  1005.981659
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  1151.177330  43.918366  1421.782051
#
#                                          LF_PCT      LF_NU         HF  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a  27.375666  98.485263  15.522603
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  22.954139  99.695397   2.108525
# c2d5d102-967c-487d-88f2-8b005a449f3e  48.335104  98.950472  13.769729
# 37eabc44-1349-4040-8896-0d113ad4811f  29.290305  98.224706  18.181913
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  54.242160  96.720007  48.215822
#
#                                         HF_PCT     HF_NU           TP  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a  0.421047  1.514737  3686.666157
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  0.070133  0.304603  3006.487251
# c2d5d102-967c-487d-88f2-8b005a449f3e  0.512671  1.049528  2685.879461
# 37eabc44-1349-4040-8896-0d113ad4811f  0.529387  1.775294  3434.520980
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  1.839473  3.279993  2621.175204
#
#                                            LF_HF  ...      KURT      SKEW  \
# uuid                                              ...
# 89df2855-56eb-4706-a23b-b39363dd605a   65.018055  ... -0.856554  0.335218
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  327.296635  ... -0.408190 -0.155286
# c2d5d102-967c-487d-88f2-8b005a449f3e   94.280910  ...  0.351789 -0.656813
# 37eabc44-1349-4040-8896-0d113ad4811f   55.328701  ... -0.504947 -0.386138
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7   29.487873  ... -0.548408 -0.154252
#
#                                       MEAN_REL_RR  MEDIAN_REL_RR  SDRR_REL_RR  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a    -0.000203      -0.000179     0.017080
# 80c795e4-aa56-4cc0-939c-19634b89cbb2    -0.000059       0.000611     0.013978
# c2d5d102-967c-487d-88f2-8b005a449f3e    -0.000011      -0.000263     0.018539
# 37eabc44-1349-4040-8896-0d113ad4811f     0.000112       0.000494     0.017761
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7    -0.000100      -0.002736     0.023715
#
#                                       RMSSD_REL_RR SDSD_REL_RR  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a      0.007969    0.007969
# 80c795e4-aa56-4cc0-939c-19634b89cbb2      0.004769    0.004769
# c2d5d102-967c-487d-88f2-8b005a449f3e      0.008716    0.008716
# 37eabc44-1349-4040-8896-0d113ad4811f      0.008660    0.008660
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7      0.013055    0.013055
#
#                                       SDRR_RMSSD_REL_RR  KURT_REL_RR  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a           2.143342    -0.856554
# 80c795e4-aa56-4cc0-939c-19634b89cbb2           2.930855    -0.408190
# c2d5d102-967c-487d-88f2-8b005a449f3e           2.127053     0.351789
# 37eabc44-1349-4040-8896-0d113ad4811f           2.050988    -0.504947
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7           1.816544    -0.548408
#
#                                       SKEW_REL_RR
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a     0.335218
# 80c795e4-aa56-4cc0-939c-19634b89cbb2    -0.155286
# c2d5d102-967c-487d-88f2-8b005a449f3e    -0.656813
# 37eabc44-1349-4040-8896-0d113ad4811f    -0.386138
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7    -0.154252
#
# [5 rows x 36 columns]

# %%
train_df.shape
# Out:
# (369289, 36)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 369289 entries, 89df2855-56eb-4706-a23b-b39363dd605a to 1f2eb52d-4f09-4921-a383-ef1bc6221789
# Data columns (total 36 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   VLF                369289 non-null  float64
#  1   VLF_PCT            369289 non-null  float64
#  2   LF                 369289 non-null  float64
#  3   LF_PCT             369289 non-null  float64
#  4   LF_NU              369289 non-null  float64
#  5   HF                 369289 non-null  float64
#  6   HF_PCT             369289 non-null  float64
#  7   HF_NU              369289 non-null  float64
#  8   TP                 369289 non-null  float64
#  9   LF_HF              369289 non-null  float64
#  10  HF_LF              369289 non-null  float64
#  11  SD1                369289 non-null  float64
#  12  SD2                369289 non-null  float64
#  13  sampen             369289 non-null  float64
#  14  higuci             369289 non-null  float64
#  15  datasetId          369289 non-null  int64
#  16  condition          369289 non-null  object
#  17  MEAN_RR            369289 non-null  float64
#  18  MEDIAN_RR          369289 non-null  float64
#  19  SDRR               369289 non-null  float64
#  20  RMSSD              369289 non-null  float64
#  21  SDSD               369289 non-null  float64
#  22  SDRR_RMSSD         369289 non-null  float64
#  23  HR                 369289 non-null  float64
#  24  pNN25              369289 non-null  float64
#  25  pNN50              369289 non-null  float64
#  26  KURT               369289 non-null  float64
#  27  SKEW               369289 non-null  float64
#  28  MEAN_REL_RR        369289 non-null  float64
#  29  MEDIAN_REL_RR      369289 non-null  float64
#  30  SDRR_REL_RR        369289 non-null  float64
#  31  RMSSD_REL_RR       369289 non-null  float64
#  32  SDSD_REL_RR        369289 non-null  float64
#  33  SDRR_RMSSD_REL_RR  369289 non-null  float64
#  34  KURT_REL_RR        369289 non-null  float64
#  35  SKEW_REL_RR        369289 non-null  float64
# dtypes: float64(34), int64(1), object(1)
# memory usage: 114.2+ MB

# %%
print(train_df['datasetId'].value_counts())
print(train_df.index.nunique())
# Out:
# 2    369289
# Name: datasetId, dtype: int64
# 369289

# %% [raw]
# 'datasetId' is the same for all the records. So, this column can be removed.
# 'uuid' does not add any information to the data, except for identification.So, drop off uuid

# %%
train_df=train_df.reset_index(drop=True)
train_df=train_df.drop(['datasetId'],axis=1)

# %%
train_df.isnull().sum()
# Out:
# VLF                  0
# VLF_PCT              0
# LF                   0
# LF_PCT               0
# LF_NU                0
# HF                   0
# HF_PCT               0
# HF_NU                0
# TP                   0
# LF_HF                0
# HF_LF                0
# SD1                  0
# SD2                  0
# sampen               0
# higuci               0
# condition            0
# MEAN_RR              0
# MEDIAN_RR            0
# SDRR                 0
# RMSSD                0
# SDSD                 0
# SDRR_RMSSD           0
# HR                   0
# pNN25                0
# pNN50                0
# KURT                 0
# SKEW                 0
# MEAN_REL_RR          0
# MEDIAN_REL_RR        0
# SDRR_REL_RR          0
# RMSSD_REL_RR         0
# SDSD_REL_RR          0
# SDRR_RMSSD_REL_RR    0
# KURT_REL_RR          0
# SKEW_REL_RR          0
# dtype: int64

# %%
train_df.describe().T
# Out:
#                       count         mean          std         min  \
# VLF                369289.0  2199.580170  1815.773422  159.480176
# VLF_PCT            369289.0    64.289242    16.774844   19.031219
# LF                 369289.0   946.530252   574.171780   90.048557
# LF_PCT             369289.0    34.095182    16.040290    2.165119
# LF_NU              369289.0    95.566718     4.123365   69.879083
# HF                 369289.0    39.245603    45.398869    0.061783
# HF_PCT             369289.0     1.615576     1.761073    0.002150
# HF_NU              369289.0     4.433282     4.123365    0.012825
# TP                 369289.0  3185.356025  1923.227187  377.692795
# LF_HF              369289.0   115.977200   360.855129    2.319952
# HF_LF              369289.0     0.048506     0.049238    0.000128
# SD1                369289.0    10.593708     2.914795    3.911344
# SD2                369289.0   154.178997   109.170222   38.307745
# sampen             369289.0     2.062471     0.206999    0.434576
# higuci             369289.0     1.182292     0.062192    1.033984
# MEAN_RR            369289.0   846.650104   124.603984  547.492221
# MEDIAN_RR          369289.0   841.965890   132.321005  517.293295
# SDRR               369289.0   109.352531    77.117025   27.233947
# RMSSD              369289.0    14.977498     4.120766    5.529742
# SDSD               369289.0    14.976767     4.120768    5.529630
# SDRR_RMSSD         369289.0     7.396597     5.143834    2.660381
# HR                 369289.0    73.941824    10.337453   48.737243
# pNN25              369289.0     9.841143     8.195574    0.000000
# pNN50              369289.0     0.866001     0.990189    0.000000
# KURT               369289.0     0.523235     1.790348   -1.894820
# SKEW               369289.0     0.041628     0.699522   -2.136278
# MEAN_REL_RR        369289.0    -0.000002     0.000163   -0.001234
# MEDIAN_REL_RR      369289.0    -0.000465     0.000868   -0.004425
# SDRR_REL_RR        369289.0     0.018571     0.005455    0.008987
# RMSSD_REL_RR       369289.0     0.009701     0.003897    0.003220
# SDSD_REL_RR        369289.0     0.009701     0.003897    0.003220
# SDRR_RMSSD_REL_RR  369289.0     2.006817     0.375845    1.169342
# KURT_REL_RR        369289.0     0.523235     1.790348   -1.894820
# SKEW_REL_RR        369289.0     0.041628     0.699522   -2.136278
#
#                            25%           50%          75%           max
# VLF                1001.189280  1.667903e+03  2654.121052  12617.977191
# VLF_PCT              52.909877  6.635024e+01    76.825032     97.738848
# LF                  545.449386  7.827163e+02  1201.432256   3291.548112
# LF_PCT               22.305936  3.204703e+01    44.647115     77.928847
# LF_NU                93.645734  9.664314e+01    98.771946     99.987175
# HF                   10.720312  2.484194e+01    45.272368    364.486936
# HF_PCT                0.346803  1.039513e+00     2.245115     13.095664
# HF_NU                 1.228054  3.356860e+00     6.354266     30.120917
# TP                 1828.147788  2.796857e+03  4052.260157  13390.684098
# LF_HF                14.737458  2.878975e+01    80.429614   7796.443096
# HF_LF                 0.012433  3.473459e-02     0.067854      0.431043
# SD1                   8.368340  1.019662e+01    12.679005     18.836107
# SD2                  90.326864  1.162211e+02   166.764850    796.852945
# sampen                2.032977  2.134214e+00     2.181929      2.234841
# higuci                1.139929  1.174293e+00     1.223621      1.361219
# MEAN_RR             760.228533  8.229514e+02   924.117422   1322.016957
# MEDIAN_RR           755.750735  8.196896e+02   916.821570   1653.122250
# SDRR                 64.205641  8.260824e+01   118.237002    563.486949
# RMSSD                11.830959  1.441592e+01    17.927144     26.629477
# SDSD                 11.830671  1.441539e+01    17.924839     26.629392
# SDRR_RMSSD            4.541896  5.952112e+00     7.919841     54.523950
# HR                   66.715776  7.421781e+01    80.334937    113.752309
# pNN25                 3.666667  7.600000e+00    13.333333     39.400000
# pNN50                 0.000000  4.666667e-01     1.466667      5.466667
# KURT                 -0.352783  4.073622e-02     0.722833     64.088107
# SKEW                 -0.359291 -6.096592e-02     0.282417      6.777800
# MEAN_REL_RR          -0.000073 -9.330777e-07     0.000069      0.001244
# MEDIAN_REL_RR        -0.000917 -3.116067e-04     0.000131      0.002095
# SDRR_REL_RR           0.014261  1.731795e-02     0.021827      0.036571
# RMSSD_REL_RR          0.006984  8.690833e-03     0.011460      0.026955
# SDSD_REL_RR           0.006984  8.690797e-03     0.011460      0.026955
# SDRR_RMSSD_REL_RR     1.749801  1.934416e+00     2.221232      3.724134
# KURT_REL_RR          -0.352783  4.073622e-02     0.722833     64.088107
# SKEW_REL_RR          -0.359291 -6.096592e-02     0.282417      6.777800

# %%
plt.figure(figsize=(20,20))
sns.heatmap(train_df.corr(),annot=True,cmap='rainbow')

# %%
corr_df=train_df.corr().abs()
corr_df.head()
# Out:
#               VLF   VLF_PCT        LF    LF_PCT     LF_NU        HF    HF_PCT  \
# VLF      1.000000  0.676628  0.026521  0.664830  0.105044  0.010441  0.389684
# VLF_PCT  0.676628  1.000000  0.541976  0.995240  0.046868  0.283068  0.460465
# LF       0.026521  0.541976  1.000000  0.570404  0.247482  0.315662  0.032871
# LF_PCT   0.664830  0.995240  0.570404  1.000000  0.043265  0.216789  0.371761
# LF_NU    0.105044  0.046868  0.247482  0.043265  1.000000  0.749237  0.840496
#
#             HF_NU        TP     LF_HF  ...      KURT      SKEW  MEAN_REL_RR  \
# VLF      0.105044  0.951800  0.126668  ...  0.050392  0.236819     0.026638
# VLF_PCT  0.046868  0.470337  0.103768  ...  0.090900  0.228209     0.002054
# LF       0.247482  0.331037  0.099452  ...  0.144318  0.075650     0.022014
# LF_PCT   0.043265  0.452276  0.082040  ...  0.106355  0.238718     0.003950
# LF_NU    1.000000  0.155373  0.281325  ...  0.216003  0.205864     0.036098
#
#          MEDIAN_REL_RR  SDRR_REL_RR  RMSSD_REL_RR  SDSD_REL_RR  \
# VLF           0.237918     0.242427      0.087994     0.087993
# VLF_PCT       0.588470     0.343214      0.333824     0.333824
# LF            0.550557     0.783464      0.524338     0.524337
# LF_PCT        0.602589     0.327483      0.288087     0.288087
# LF_NU         0.121910     0.247067      0.582438     0.582438
#
#          SDRR_RMSSD_REL_RR  KURT_REL_RR  SKEW_REL_RR
# VLF               0.303226     0.050392     0.236819
# VLF_PCT           0.277593     0.090900     0.228209
# LF                0.077445     0.144318     0.075650
# LF_PCT            0.215372     0.106355     0.238718
# LF_NU             0.760120     0.216003     0.205864
#
# [5 rows x 34 columns]

# %% [markdown]
# Many Features seem to be highly correlated. We can remove them, so that we could have a managable dataset.

# %%
#sorting corrolation of target variable and predictors 
corr =corr_df.corrwith(corr_df["HR"]).sort_values(ascending=False)

# %%
co_df=pd.DataFrame(corr)
co_df.columns=['corr']

# %%
co_df
# Out:
#                        corr
# HR                 1.000000
# MEDIAN_RR          0.963231
# MEAN_RR            0.894705
# HF_NU              0.860224
# LF_NU              0.860224
# SDRR_RMSSD_REL_RR  0.858907
# HF_LF              0.850894
# HF_PCT             0.775173
# HF                 0.687687
# LF_HF              0.601420
# higuci             0.498700
# SDSD_REL_RR        0.389261
# RMSSD_REL_RR       0.389260
# KURT_REL_RR        0.099743
# KURT               0.099743
# SKEW_REL_RR        0.002619
# SKEW               0.002619
# SDRR_REL_RR       -0.141452
# VLF               -0.187857
# sampen            -0.197939
# TP                -0.218365
# RMSSD             -0.248048
# SD1               -0.248128
# SDSD              -0.248128
# pNN25             -0.269539
# MEAN_REL_RR       -0.271477
# VLF_PCT           -0.285897
# SDRR              -0.305053
# SD2               -0.305263
# pNN50             -0.331581
# SDRR_RMSSD        -0.360571
# LF_PCT            -0.369575
# LF                -0.371807
# MEDIAN_REL_RR     -0.564955

# %%
selected_features=co_df.loc[(co_df['corr']<0.87) & (co_df['corr']>=0.5)]
selected_features.reset_index()
# Out:
#                index      corr
# 0              HF_NU  0.860224
# 1              LF_NU  0.860224
# 2  SDRR_RMSSD_REL_RR  0.858907
# 3              HF_LF  0.850894
# 4             HF_PCT  0.775173
# 5                 HF  0.687687
# 6              LF_HF  0.601420

# %%
corr= selected_features.index.tolist()
corr
# Out:
# ['HF_NU', 'LF_NU', 'SDRR_RMSSD_REL_RR', 'HF_LF', 'HF_PCT', 'HF', 'LF_HF']

# %%
# filtering out variables highly correlated 
c=corr_df.unstack()
co=c.sort_values(kind='quicksort')
co_df=pd.DataFrame(co)
co_df.columns=['corr']

# %%
remove_features=co_df.loc[co_df['corr']>=0.75]
remove_features
# Out:
#                                    corr
# pNN50             SDRR_REL_RR  0.756253
# SDRR_REL_RR       pNN50        0.756253
# HF_LF             HF           0.757545
# HF                HF_LF        0.757545
# SDRR_RMSSD_REL_RR HF_NU        0.760120
# ...                                 ...
# SDRR_RMSSD        SDRR_RMSSD   1.000000
# SDSD              SDSD         1.000000
# SKEW              SKEW         1.000000
# LF_NU             HF_NU        1.000000
# HF_NU             LF_NU        1.000000
#
# [126 rows x 1 columns]

# %%
remove_features.reset_index(level=[0,1],inplace=True)
remove_features.rename(columns={'level_0':'feature1','level_1':'feature2'},inplace=True)
remove_features=remove_features[remove_features['feature1']!=remove_features['feature2']].reset_index(drop=True)
remove_features.drop_duplicates(subset='corr',keep='first').reset_index(drop=True)
remove_features
# Out:
#              feature1     feature2      corr
# 0               pNN50  SDRR_REL_RR  0.756253
# 1         SDRR_REL_RR        pNN50  0.756253
# 2               HF_LF           HF  0.757545
# 3                  HF        HF_LF  0.757545
# 4   SDRR_RMSSD_REL_RR        HF_NU  0.760120
# ..                ...          ...       ...
# 87        KURT_REL_RR         KURT  1.000000
# 88               SKEW  SKEW_REL_RR  1.000000
# 89               KURT  KURT_REL_RR  1.000000
# 90              LF_NU        HF_NU  1.000000
# 91              HF_NU        LF_NU  1.000000
#
# [92 rows x 3 columns]

# %%
remove_features.shape
# Out:
# (92, 3)

# %%
remove_list=remove_features['feature2'].to_list()
remove_list=list(set(remove_list))
remove_list
# Out:
# ['pNN50',
#  'RMSSD',
#  'SDRR_RMSSD',
#  'SD1',
#  'LF',
#  'higuci',
#  'HF_LF',
#  'KURT',
#  'pNN25',
#  'HF',
#  'SDRR_REL_RR',
#  'MEDIAN_RR',
#  'SKEW_REL_RR',
#  'SDRR',
#  'LF_PCT',
#  'HF_PCT',
#  'TP',
#  'KURT_REL_RR',
#  'SKEW',
#  'SDSD',
#  'VLF',
#  'SDSD_REL_RR',
#  'HR',
#  'RMSSD_REL_RR',
#  'HF_NU',
#  'LF_NU',
#  'MEAN_RR',
#  'SDRR_RMSSD_REL_RR',
#  'SD2',
#  'VLF_PCT']

# %% [raw]
# feature1 remove comparision with feature2
# # remove_list1=remove_features['feature1'].to_list()
# # remove_list1=list(set(remove_list1))
# # len(list(set(remove_list1).intersection(set(remove_list))))

# %%
## excluding the Target Variable
remove_list.remove('HR')
len(remove_list)
# Out:
# 29

# %% [markdown]
# The above 29 columns need to be removed

# %% [raw]
# Intersection of highly correlated variable with HR and removed list

# %%
Intersections= [x for x in corr if x in remove_list]
# Or list(set(high_corr).intersection(set(remove_list)))

# %%
remove_list = [x for x in remove_list if x not in Intersections]

# %%
remove_list
# Out:
# ['pNN50',
#  'RMSSD',
#  'SDRR_RMSSD',
#  'SD1',
#  'LF',
#  'higuci',
#  'KURT',
#  'pNN25',
#  'SDRR_REL_RR',
#  'MEDIAN_RR',
#  'SKEW_REL_RR',
#  'SDRR',
#  'LF_PCT',
#  'TP',
#  'KURT_REL_RR',
#  'SKEW',
#  'SDSD',
#  'VLF',
#  'SDSD_REL_RR',
#  'RMSSD_REL_RR',
#  'MEAN_RR',
#  'SD2',
#  'VLF_PCT']

# %%
train_removedFeatures=train_df.drop(remove_list,axis=1)
train_removedFeatures.shape
# Out:
# (369289, 12)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# Univariate Analysis on the above feature reduced and sampled dataset - sample_train, which contains 14722 rows and 5 columns

# %% [markdown]
# ##### Comparing the Univariate Dist of the population and the sample

# %%
## Population distplots
num_features=train_removedFeatures.drop('condition',axis=1)
for i in num_features.columns:
    sns.distplot(num_features[i],hist=False)
    plt.show()

# %% [markdown]
# The distributions of the population and sample match well. So, our sample is random and is a good representation of the Original dataset.

# %%
sns.countplot(train_df['condition'])

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.figure(figsize=(30,20))
pos=1
for i in num_features.columns:
    plt.subplot(3,5,pos)
    sns.regplot(x=i,y='HR',data=num_features)
    pos=pos+1

# %%
sns.boxplot(y='HR',x='condition',data=train_removedFeatures)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(train_removedFeatures['condition'])
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping)
# Out:
# {'interruption': 0, 'no stress': 1, 'time pressure': 2}

# %%
train_removedFeatures['condition'] =train_removedFeatures['condition'].astype('category').cat.codes
train_removedFeatures[['condition', 'HR']].corr()['HR'][:]
# Out:
# condition   -0.090163
# HR           1.000000
# Name: HR, dtype: float64

# %%
# Separating dependent and independent variables
X = train_removedFeatures.drop('HR',axis=1)
y = train_removedFeatures['HR']

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X , y, test_size=0.3, random_state=7)

# %%
from sklearn.preprocessing import LabelEncoder
### label encode the categorical values and convert them to numbers 
le = LabelEncoder()
le.fit(X_train['condition'].astype(str))
X_train['condition'] = le.transform(X_train['condition'].astype(str))
X_test['condition'] = le.transform( X_test['condition'].astype(str))

# %%
X_train.head()
# Out:
#             LF_NU         HF    HF_PCT      HF_NU       LF_HF     HF_LF  \
# 33386   91.356078  70.463296  0.729473   8.643922   10.568823  0.094618
# 75792   88.458181  34.974898  3.921304  11.541819    7.664145  0.130478
# 232438  99.746742   1.277434  0.047695   0.253258  393.854190  0.002539
# 72034   97.949798  30.117393  1.384341   2.050202   47.775672  0.020931
# 334139  96.141330  53.282548  2.406464   3.858670   24.915668  0.040135
#
#           sampen  condition  MEAN_REL_RR  MEDIAN_REL_RR  SDRR_RMSSD_REL_RR
# 33386   1.783188          0     0.000308       0.000216           1.690085
# 75792   2.181054          0     0.000027       0.000029           1.609407
# 232438  1.975144          2    -0.000124      -0.000840           2.728885
# 72034   2.200582          2    -0.000093      -0.001441           1.896438
# 334139  2.197975          1    -0.000041      -0.001508           1.735874

# %%
#Degree 2
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

pipeline = Pipeline([
    ('poly',PolynomialFeatures(degree=2, interaction_only=True)),
    ('reg', DecisionTreeRegressor(random_state=7))
])

pipeline.fit(X_train, y_train)

print(pipeline.score(X_train, y_train))

print(pipeline.score(X_test, y_test))
# Out:
# 1.0
# 0.9981029501799473

# %%
#Degree 3
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
pipeline = Pipeline([
    ('poly', PolynomialFeatures(degree=3, interaction_only=True)),
    ('reg', DecisionTreeRegressor(random_state=7))
])

pipeline.fit(X_train, y_train)

print(pipeline.score(X_train, y_train))

print(pipeline.score(X_test, y_test))
# Out:
# 1.0
# 0.9978398395107433

# %% [markdown]
# # Model:
#
# 1. Different Models:

# %%
from sklearn.model_selection import cross_val_score, KFold
k = KFold(random_state=7, n_splits=5, shuffle=True) # KFold will split the data in 5 equal parts

# %%
# Linear Regression
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('reg', LinearRegression())
])

pipeline.fit(X_train, y_train)

# Make predictions using the testing set
y_predict= pipeline.predict(X_test)

# The mean squared error
print('Mean absolute error: %.2f'
      % mean_absolute_error(y_test, y_predict))

print('Test Accuracy: %.3f' % pipeline.score(X_test, y_test))
# Out:
# Mean squared error: 4.60
# Test Accuracy: 0.659

# %%
# Decision Tree
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state=7)
model.fit(X_train, y_train)
y_predict= model.predict(X_test)

# The mean squared error
print('Mean absolute error: %.2f'
      % mean_absolute_error(y_test, y_predict))
#score = cross_val_score(model, X_test, y_test)
print('Model Score: %.3f' % model.score(X_test, y_test))
# Out:
# Mean squared error: 0.07
# Model Score: 0.997

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
model = RandomForestRegressor(random_state=7)

model.fit(X_train, y_train)

y_predict= model.predict(X_test)
# The mean squared error
print('Mean absolute error: %.2f'
      % mean_absolute_error(y_test, y_predict))
#score = cross_val_score(model, X_test, y_test)
print('Model Score: %.3f' % model.score(X_test, y_test))
# Out:
# Mean absolute error: 0.08
# Model Score: 0.999

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_predict, 'Condition':X_test.condition })
df.sort_values(by=['Actual'], inplace=True)
df
# Out:
#             Actual   Predicted  Condition
# 181007   48.752380   48.746399          2
# 54027    48.758130   48.763879          2
# 312983   48.758925   48.756719          2
# 115193   48.768530   48.778600          2
# 366683   48.773444   48.785105          2
# ...            ...         ...        ...
# 357008  113.726684  113.686963          0
# 216739  113.727747  113.634081          0
# 168564  113.728784  113.639323          0
# 92663   113.732023  113.706760          0
# 98160   113.737415  113.701647          0
#
# [110787 rows x 3 columns]

# %%
# Bagging

from sklearn.ensemble import BaggingRegressor

model = BaggingRegressor(random_state=7)

model.fit(X_train, y_train)

y_predict= model.predict(X_test)
# The mean squared error
print('Mean absolute error: %.2f'
      % mean_absolute_error(y_test, y_predict))
#score = cross_val_score(model, X_test, y_test)
print('Model Score: %.3f' % model.score(X_test, y_test))
# Out:
# Mean squared error: 0.08
# Model Score: 0.999

# %%
# AdaBoost
from sklearn.ensemble import AdaBoostRegressor

model = AdaBoostRegressor(random_state=7)

model.fit(X_train, y_train)

y_predict= model.predict(X_test)
# The mean squared error
print('Mean absolute error: %.2f'
      % mean_absolute_error(y_test, y_predict))
#score = cross_val_score(model, X_test, y_test)
print('Model Score: %.3f' % model.score(X_test, y_test))
# Out:
# Mean squared error: 1.52
# Model Score: 0.971

# %%
# Gradient Boosting
from sklearn.ensemble import GradientBoostingRegressor

model = GradientBoostingRegressor(random_state=7)

model.fit(X_train, y_train)
y_predict= model.predict(X_test)
# The mean squared error
print('Mean absolute error: %.2f'
      % mean_absolute_error(y_test, y_predict))
#score = cross_val_score(model, X_test, y_test)
print('Model Score: %.3f' % model.score(X_test, y_test))
# Out:
# Mean squared error: 2.44
# Model Score: 0.896

# %% [markdown]
# ### GridSearchCV
